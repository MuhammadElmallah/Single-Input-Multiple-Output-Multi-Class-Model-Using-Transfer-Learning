# %%
from keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load the data from Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = load_model('/content/drive/MyDrive/task/best_mob_model.h5')

# %%
#model.summary()

# %%
path = '/content/drive/MyDrive/task/Coffee Leaves/images/'

# %%
c = open('/content/drive/MyDrive/task/data_outputt.txt', 'a+')
for i in range(1, 1748):
  img = load_img(path + str(i) + '.jpg', target_size=(224, 224, 3))
  img = img_to_array(img) / 255
  img = np.expand_dims(img, axis = 0)
  a = model.predict(img)
  m = np.round(a[0])
  n = np.round(a[1])
  c.write(str(i) + ',' + str(n[0][0]) + ',' + str(n[0][1]) + ',' + str(n[0][2]) + ',' + str(n[0][3]) + ',' + str(m[0][0]) + ',' + str(m[0][0]) + '\n')

# %%
c.close()

# %%
txt_file = pd.read_csv('/content/drive/MyDrive/task/data_outputt.txt', header = None)
  
# adding column headings
txt_file.columns = ['id','miner', 'rust', 'phoma', 'cercospora', 'severity', 'predominant_stress']
  
# store dataframe into csv file
txt_file.to_csv('/content/drive/MyDrive/task/MobileNet__output.csv', index = None)
