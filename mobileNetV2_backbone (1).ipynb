# %% [markdown]
# ## ***Import the Dependencies***

# %%
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.layers import Dense, Flatten, Dropout
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ***`Loading and Preprocessing the Data`***

# %%
# Load the data from Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip the data
# !unzip '/content/drive/MyDrive/task/Coffee Leaves.zip' -d '/content/drive/MyDrive/task'
# Data is already Unzipped

# %%
# Read the Csv File into the data  frame
data_frame = pd.read_csv('/content/drive/MyDrive/task/Coffee Leaves/dataset.csv')

# Convert the Values in the 'id' columns of the csv file to string. This required by the ImageDataGenerator
data_frame['id'] = data_frame['id'].apply(lambda x: str(x) + '.jpg')

# %%
# The ImageDataGenerator will create data generators for training, validation and test sets of data.
# However the output of those generators will be tupels (x, y).
# we need to split the targets (y) to feed them to the two branches of the model.
# We will do this using the following function.

def split_outputs(generator):
    while True:
        data = generator.next()
        x = data[0]
        y = np.split(data[1], [2], axis = 1)   # Split y into two subsections (y[0:2], y[2:])
        yield x, y

# %% [markdown]
# # ***Define The Hyperparameters***

# %%
# Target Labels (Y_true)
targets = ['predominant_stress','severity', 'miner', 'rust', 'phoma', 'cercospora']

m = data_frame.shape[0]                                       # Number of exampels in the dataset
sr1 = m * 8 // 10                                             # split_ratio 1
sr2 = m * 9 // 10                                             # split_ratio 2 
training_exampels = sr1                                       # Number of Training exampels
validation_exampels = sr2 - sr1                               # Number of Validation exampels
testing_exampels = m - sr2                                    # Number of Testing exampels is
batch_size = 32                                               # Batch Size
input_shape = (224, 224, 3)                                   # Shape of the Input Image

epochs = 60                                                    # Number of Epochs
steps_per_epoch = training_exampels // batch_size             # Steps per Epoch
validation_steps = validation_exampels // batch_size          # Validation Steps
testing_steps = testing_exampels / batch_size                 # Testing Steps

# %%
# we will split the data into three subsets, training, validation and test.
# Splitting of Data will be [80 % - 10 % - 10 %]

print('The Whole Dataset Consists of :-    ', m, 'Exampels')
print('Number of Training exampels is :-   ', training_exampels, 'Exampels')
print('Number of Validation exampels is :- ', validation_exampels, 'Exampels')
print('Number of Testing exampels is :-    ', testing_exampels, 'Exampels')
# Out:
# The Whole Dataset Consists of :-     1747 Exampels
# Number of Training exampels is :-    1397 Exampels
# Number of Validation exampels is :-  175 Exampels
# Number of Testing exampels is :-     175 Exampels

# %%
# Loading the training set.
# The ImageDataGenerator is used for data Augmentation.
# Augmentaion Techniques used are rotaion and flipping (horizontal and vertical)

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 10,
                                   horizontal_flip = True,
                                   vertical_flip = True)

train_generator = split_outputs(train_datagen.flow_from_dataframe(dataframe = data_frame[:sr1], directory = '/content/drive/MyDrive/task/Coffee Leaves/images/',
                                                    x_col = 'id', y_col = targets, batch_size = batch_size, seed = 42, shuffle = True,
                                                    class_mode = 'raw', target_size = (224, 224)))
# Out:
# Found 1397 validated image filenames.

# %%
# Same for Validation and Test Data
test_datagen = ImageDataGenerator(rescale=1./255.)
valid_generator = split_outputs(test_datagen.flow_from_dataframe( dataframe = data_frame[sr1:sr2], directory = '/content/drive/MyDrive/task/Coffee Leaves/images/',
                                                   x_col = 'id', y_col = targets, batch_size = batch_size, seed = 42, shuffle = True,
                                                    class_mode = 'raw', target_size=(224, 224)))


test_generator = split_outputs(test_datagen.flow_from_dataframe( dataframe = data_frame[sr2:], directory = '/content/drive/MyDrive/task/Coffee Leaves/images/',
                                                   x_col = 'id', y_col = targets, batch_size = batch_size, seed = 42, shuffle = False,
                                                    class_mode = 'raw', target_size=(224, 224)))
# Out:
# Found 175 validated image filenames.
# Found 175 validated image filenames.

# %% [markdown]
# # ***Creating The Model***

# %%
# We will use transfer learning and we will use Resnet50 as the base model.
base_model = MobileNetV2(weights = 'imagenet', include_top = False, input_shape = input_shape)

last_output = base_model.output

x = Flatten()(last_output)                      # We will feed this to the two branches of our Model.

# Because the accuary of the classification branch was not that good we will add two fully connected layers before the
# classification output and only one layer before the regression one.
x1 = Dense(1024, activation='relu')(x)
x1 = Dropout(0.2)(x1)
x1 = Dense(512, activation='relu')(x1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
# Now We will Defing the Two branches.
# The First branch is for the Regression part of the Problem. I will Contain two neurons, one for predicting the predominant stress
# and the other one for predicting the Severity. 
# Relu is the activation function used in this branch, Rectified Linear Unit
out1 = Dense(2, activation='linear', name = 'regression_branch')(x1)

# The Second branch is for the Classification part of the Problem. I will Contain Four neurons, one for each of the stresses
# Sigmoid is the activation function used in this branch because this is a multi-label task.
out2 = Dense(4, activation='sigmoid', name = 'classification_branch')(x1)

# %%
# Creating the Model
model = Model(inputs=base_model.input, outputs=[out1, out2])

# %%
# Visualize The Model
plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Summarize The Model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 62720)        0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         64226304    flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout[0][0]
# __________________________________________________________________________________________________
# regression_branch (Dense)       (None, 2)            1026        dense_1[0][0]
# __________________________________________________________________________________________________
# classification_branch (Dense)   (None, 4)            2052        dense_1[0][0]
# ==================================================================================================
# Total params: 67,012,166
# Trainable params: 66,978,054
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %% [markdown]
# # ***Compiling The Model***

# %%
# Creating a ModelCheckoint callback for each branch of the model to save the best mode.
regression_checkpointer = ModelCheckpoint(monitor= 'val_regression_branch_loss',
                                              filepath='/content/drive/MyDrive/task/mobnet_val_regression_branch_loss.model.hdf5',
                                              save_best_only=True)

classification_checkpointer = ModelCheckpoint(monitor= 'val_classification_branch_loss',
                                              filepath='/content/drive/MyDrive/task/mobnet_val_classification_branch_loss.model.hdf5',
                                              save_best_only=True)

# Compile The Model
# We will use Stochastic Gradient Descent as our Optimizer.
# For the regression Branch we will use 'Mean Squared Error' as the loss function
# For the Classification Branch we will use 'Binary Cross Entropy'
model.compile(optimizer = 'adam', loss=['mse', 'binary_crossentropy'], metrics=['accuracy'])

# %% [markdown]
# # ***Training The Model***

# %%
history = model.fit_generator(train_generator, epochs=epochs, verbose=1,
                              validation_data=valid_generator,
                              callbacks=[regression_checkpointer, classification_checkpointer],
                              steps_per_epoch=steps_per_epoch, validation_steps=validation_steps)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.8783 - regression_branch_loss: 0.5869 - classification_branch_loss: 0.2914 - regression_branch_accuracy: 0.7516 - classification_branch_accuracy: 0.7722 - val_loss: 116.9476 - val_regression_branch_loss: 109.6005 - val_classification_branch_loss: 7.3471 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.6750
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.8254 - regression_branch_loss: 0.5533 - classification_branch_loss: 0.2720 - regression_branch_accuracy: 0.7568 - classification_branch_accuracy: 0.8081 - val_loss: 87.5432 - val_regression_branch_loss: 80.9222 - val_classification_branch_loss: 6.6210 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.6687
# Epoch 3/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.8409 - regression_branch_loss: 0.5687 - classification_branch_loss: 0.2723 - regression_branch_accuracy: 0.7553 - classification_branch_accuracy: 0.7993 - val_loss: 64.4016 - val_regression_branch_loss: 58.8295 - val_classification_branch_loss: 5.5722 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.6375
# Epoch 4/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.7877 - regression_branch_loss: 0.5193 - classification_branch_loss: 0.2684 - regression_branch_accuracy: 0.7758 - classification_branch_accuracy: 0.7971 - val_loss: 54.0705 - val_regression_branch_loss: 50.5935 - val_classification_branch_loss: 3.4771 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.6562
# Epoch 5/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.7446 - regression_branch_loss: 0.4959 - classification_branch_loss: 0.2487 - regression_branch_accuracy: 0.7678 - classification_branch_accuracy: 0.7934 - val_loss: 38.0971 - val_regression_branch_loss: 34.8568 - val_classification_branch_loss: 3.2403 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.6438
# Epoch 6/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.7536 - regression_branch_loss: 0.5042 - classification_branch_loss: 0.2494 - regression_branch_accuracy: 0.7795 - classification_branch_accuracy: 0.8190 - val_loss: 14.9980 - val_regression_branch_loss: 11.7046 - val_classification_branch_loss: 3.2934 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.6438
# Epoch 7/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.7500 - regression_branch_loss: 0.5039 - classification_branch_loss: 0.2460 - regression_branch_accuracy: 0.7641 - classification_branch_accuracy: 0.8007 - val_loss: 15.0086 - val_regression_branch_loss: 12.3908 - val_classification_branch_loss: 2.6178 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.3625
# Epoch 8/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.7114 - regression_branch_loss: 0.4811 - classification_branch_loss: 0.2303 - regression_branch_accuracy: 0.7744 - classification_branch_accuracy: 0.8315 - val_loss: 10.8569 - val_regression_branch_loss: 7.8185 - val_classification_branch_loss: 3.0384 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.3562
# Epoch 9/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.6731 - regression_branch_loss: 0.4440 - classification_branch_loss: 0.2291 - regression_branch_accuracy: 0.7736 - classification_branch_accuracy: 0.8278 - val_loss: 9.9448 - val_regression_branch_loss: 7.6692 - val_classification_branch_loss: 2.2756 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.4437
# Epoch 10/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.6058 - regression_branch_loss: 0.3915 - classification_branch_loss: 0.2143 - regression_branch_accuracy: 0.7458 - classification_branch_accuracy: 0.8300 - val_loss: 6.4983 - val_regression_branch_loss: 4.2314 - val_classification_branch_loss: 2.2668 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.3438
# Epoch 11/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.6248 - regression_branch_loss: 0.4124 - classification_branch_loss: 0.2124 - regression_branch_accuracy: 0.7700 - classification_branch_accuracy: 0.8366 - val_loss: 4.4247 - val_regression_branch_loss: 2.5700 - val_classification_branch_loss: 1.8546 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5750
# Epoch 12/60
# 43/43 [==============================] - 64s 2s/step - loss: 0.5870 - regression_branch_loss: 0.3819 - classification_branch_loss: 0.2052 - regression_branch_accuracy: 0.7575 - classification_branch_accuracy: 0.8278 - val_loss: 3.8497 - val_regression_branch_loss: 1.6888 - val_classification_branch_loss: 2.1609 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.3438
# Epoch 13/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.5959 - regression_branch_loss: 0.3922 - classification_branch_loss: 0.2037 - regression_branch_accuracy: 0.7531 - classification_branch_accuracy: 0.8454 - val_loss: 3.1517 - val_regression_branch_loss: 1.5067 - val_classification_branch_loss: 1.6449 - val_regression_branch_accuracy: 0.8062 - val_classification_branch_accuracy: 0.2812
# Epoch 14/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.5349 - regression_branch_loss: 0.3350 - classification_branch_loss: 0.1999 - regression_branch_accuracy: 0.7795 - classification_branch_accuracy: 0.8374 - val_loss: 2.7738 - val_regression_branch_loss: 1.1378 - val_classification_branch_loss: 1.6360 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.5875
# Epoch 15/60
# 43/43 [==============================] - 65s 2s/step - loss: 0.5729 - regression_branch_loss: 0.3736 - classification_branch_loss: 0.1993 - regression_branch_accuracy: 0.7619 - classification_branch_accuracy: 0.8256 - val_loss: 2.8833 - val_regression_branch_loss: 1.0372 - val_classification_branch_loss: 1.8462 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.3875
# Epoch 16/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.4958 - regression_branch_loss: 0.3147 - classification_branch_loss: 0.1810 - regression_branch_accuracy: 0.7744 - classification_branch_accuracy: 0.8168 - val_loss: 3.0043 - val_regression_branch_loss: 1.0747 - val_classification_branch_loss: 1.9295 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.5625
# Epoch 17/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.5583 - regression_branch_loss: 0.3486 - classification_branch_loss: 0.2097 - regression_branch_accuracy: 0.7758 - classification_branch_accuracy: 0.8220 - val_loss: 2.7544 - val_regression_branch_loss: 1.0790 - val_classification_branch_loss: 1.6754 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.3562
# Epoch 18/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.4924 - regression_branch_loss: 0.3176 - classification_branch_loss: 0.1748 - regression_branch_accuracy: 0.7546 - classification_branch_accuracy: 0.8608 - val_loss: 2.8004 - val_regression_branch_loss: 1.5881 - val_classification_branch_loss: 1.2122 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.4375
# Epoch 19/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.4808 - regression_branch_loss: 0.3008 - classification_branch_loss: 0.1800 - regression_branch_accuracy: 0.7744 - classification_branch_accuracy: 0.8593 - val_loss: 2.5728 - val_regression_branch_loss: 1.1637 - val_classification_branch_loss: 1.4091 - val_regression_branch_accuracy: 0.8938 - val_classification_branch_accuracy: 0.4500
# Epoch 20/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.4654 - regression_branch_loss: 0.3087 - classification_branch_loss: 0.1567 - regression_branch_accuracy: 0.7546 - classification_branch_accuracy: 0.8557 - val_loss: 2.9206 - val_regression_branch_loss: 1.2531 - val_classification_branch_loss: 1.6674 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.3500
# Epoch 21/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.4870 - regression_branch_loss: 0.3132 - classification_branch_loss: 0.1738 - regression_branch_accuracy: 0.7641 - classification_branch_accuracy: 0.8601 - val_loss: 2.1954 - val_regression_branch_loss: 1.1435 - val_classification_branch_loss: 1.0518 - val_regression_branch_accuracy: 0.9000 - val_classification_branch_accuracy: 0.4250
# Epoch 22/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.4368 - regression_branch_loss: 0.2823 - classification_branch_loss: 0.1545 - regression_branch_accuracy: 0.7582 - classification_branch_accuracy: 0.8549 - val_loss: 1.8683 - val_regression_branch_loss: 1.0186 - val_classification_branch_loss: 0.8497 - val_regression_branch_accuracy: 0.9000 - val_classification_branch_accuracy: 0.5250
# Epoch 23/60
# 43/43 [==============================] - 64s 2s/step - loss: 0.4574 - regression_branch_loss: 0.2901 - classification_branch_loss: 0.1673 - regression_branch_accuracy: 0.7736 - classification_branch_accuracy: 0.8440 - val_loss: 2.3704 - val_regression_branch_loss: 1.2163 - val_classification_branch_loss: 1.1540 - val_regression_branch_accuracy: 0.8875 - val_classification_branch_accuracy: 0.4187
# Epoch 24/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.4358 - regression_branch_loss: 0.2811 - classification_branch_loss: 0.1547 - regression_branch_accuracy: 0.7538 - classification_branch_accuracy: 0.8491 - val_loss: 2.0817 - val_regression_branch_loss: 1.0567 - val_classification_branch_loss: 1.0250 - val_regression_branch_accuracy: 0.9500 - val_classification_branch_accuracy: 0.4625
# Epoch 25/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.3971 - regression_branch_loss: 0.2400 - classification_branch_loss: 0.1570 - regression_branch_accuracy: 0.7663 - classification_branch_accuracy: 0.8542 - val_loss: 1.9846 - val_regression_branch_loss: 1.0591 - val_classification_branch_loss: 0.9255 - val_regression_branch_accuracy: 0.9125 - val_classification_branch_accuracy: 0.4125
# Epoch 26/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.4130 - regression_branch_loss: 0.2658 - classification_branch_loss: 0.1472 - regression_branch_accuracy: 0.7802 - classification_branch_accuracy: 0.8733 - val_loss: 1.7318 - val_regression_branch_loss: 1.0679 - val_classification_branch_loss: 0.6639 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.6687
# Epoch 27/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.4177 - regression_branch_loss: 0.2587 - classification_branch_loss: 0.1591 - regression_branch_accuracy: 0.7458 - classification_branch_accuracy: 0.8469 - val_loss: 2.0769 - val_regression_branch_loss: 1.3168 - val_classification_branch_loss: 0.7602 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5125
# Epoch 28/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3960 - regression_branch_loss: 0.2546 - classification_branch_loss: 0.1414 - regression_branch_accuracy: 0.7700 - classification_branch_accuracy: 0.8681 - val_loss: 1.8082 - val_regression_branch_loss: 1.1702 - val_classification_branch_loss: 0.6380 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5437
# Epoch 29/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.3466 - regression_branch_loss: 0.2084 - classification_branch_loss: 0.1383 - regression_branch_accuracy: 0.7626 - classification_branch_accuracy: 0.8674 - val_loss: 2.0659 - val_regression_branch_loss: 1.1980 - val_classification_branch_loss: 0.8680 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.4688
# Epoch 30/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3604 - regression_branch_loss: 0.2147 - classification_branch_loss: 0.1456 - regression_branch_accuracy: 0.7670 - classification_branch_accuracy: 0.8623 - val_loss: 2.0844 - val_regression_branch_loss: 1.2336 - val_classification_branch_loss: 0.8508 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.5750
# Epoch 31/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3490 - regression_branch_loss: 0.2216 - classification_branch_loss: 0.1274 - regression_branch_accuracy: 0.7700 - classification_branch_accuracy: 0.8535 - val_loss: 1.8439 - val_regression_branch_loss: 1.1970 - val_classification_branch_loss: 0.6469 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.5375
# Epoch 32/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3275 - regression_branch_loss: 0.2018 - classification_branch_loss: 0.1257 - regression_branch_accuracy: 0.7648 - classification_branch_accuracy: 0.8608 - val_loss: 1.8117 - val_regression_branch_loss: 1.2017 - val_classification_branch_loss: 0.6100 - val_regression_branch_accuracy: 0.9000 - val_classification_branch_accuracy: 0.6062
# Epoch 33/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.3461 - regression_branch_loss: 0.2128 - classification_branch_loss: 0.1333 - regression_branch_accuracy: 0.7678 - classification_branch_accuracy: 0.8505 - val_loss: 2.0002 - val_regression_branch_loss: 1.1233 - val_classification_branch_loss: 0.8770 - val_regression_branch_accuracy: 0.9062 - val_classification_branch_accuracy: 0.4563
# Epoch 34/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3193 - regression_branch_loss: 0.1941 - classification_branch_loss: 0.1252 - regression_branch_accuracy: 0.7626 - classification_branch_accuracy: 0.8564 - val_loss: 1.5782 - val_regression_branch_loss: 1.0193 - val_classification_branch_loss: 0.5588 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.6375
# Epoch 35/60
# 43/43 [==============================] - 61s 1s/step - loss: 0.3244 - regression_branch_loss: 0.1991 - classification_branch_loss: 0.1253 - regression_branch_accuracy: 0.7722 - classification_branch_accuracy: 0.8352 - val_loss: 1.7780 - val_regression_branch_loss: 1.0535 - val_classification_branch_loss: 0.7245 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5063
# Epoch 36/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.3348 - regression_branch_loss: 0.2099 - classification_branch_loss: 0.1249 - regression_branch_accuracy: 0.7663 - classification_branch_accuracy: 0.8593 - val_loss: 1.5360 - val_regression_branch_loss: 0.9833 - val_classification_branch_loss: 0.5527 - val_regression_branch_accuracy: 0.9125 - val_classification_branch_accuracy: 0.6062
# Epoch 37/60
# 43/43 [==============================] - 63s 1s/step - loss: 0.3240 - regression_branch_loss: 0.2028 - classification_branch_loss: 0.1212 - regression_branch_accuracy: 0.7817 - classification_branch_accuracy: 0.8308 - val_loss: 2.0615 - val_regression_branch_loss: 1.2631 - val_classification_branch_loss: 0.7984 - val_regression_branch_accuracy: 0.9000 - val_classification_branch_accuracy: 0.4875
# Epoch 38/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.2854 - regression_branch_loss: 0.1772 - classification_branch_loss: 0.1082 - regression_branch_accuracy: 0.7685 - classification_branch_accuracy: 0.8381 - val_loss: 1.9102 - val_regression_branch_loss: 1.2072 - val_classification_branch_loss: 0.7030 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.5312
# Epoch 39/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.3487 - regression_branch_loss: 0.2251 - classification_branch_loss: 0.1236 - regression_branch_accuracy: 0.7660 - classification_branch_accuracy: 0.8299 - val_loss: 1.8458 - val_regression_branch_loss: 1.1225 - val_classification_branch_loss: 0.7233 - val_regression_branch_accuracy: 0.8938 - val_classification_branch_accuracy: 0.4812
# Epoch 40/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.2914 - regression_branch_loss: 0.1768 - classification_branch_loss: 0.1146 - regression_branch_accuracy: 0.7685 - classification_branch_accuracy: 0.7905 - val_loss: 1.9799 - val_regression_branch_loss: 1.1686 - val_classification_branch_loss: 0.8113 - val_regression_branch_accuracy: 0.9375 - val_classification_branch_accuracy: 0.4563
# Epoch 41/60
# 43/43 [==============================] - 60s 1s/step - loss: 0.2956 - regression_branch_loss: 0.1856 - classification_branch_loss: 0.1100 - regression_branch_accuracy: 0.7582 - classification_branch_accuracy: 0.8337 - val_loss: 1.8612 - val_regression_branch_loss: 1.0265 - val_classification_branch_loss: 0.8347 - val_regression_branch_accuracy: 0.9312 - val_classification_branch_accuracy: 0.4125
# Epoch 42/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2941 - regression_branch_loss: 0.1840 - classification_branch_loss: 0.1101 - regression_branch_accuracy: 0.7780 - classification_branch_accuracy: 0.8029 - val_loss: 1.7456 - val_regression_branch_loss: 1.0451 - val_classification_branch_loss: 0.7005 - val_regression_branch_accuracy: 0.9000 - val_classification_branch_accuracy: 0.5125
# Epoch 43/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2757 - regression_branch_loss: 0.1683 - classification_branch_loss: 0.1074 - regression_branch_accuracy: 0.7678 - classification_branch_accuracy: 0.8234 - val_loss: 1.8945 - val_regression_branch_loss: 0.9633 - val_classification_branch_loss: 0.9312 - val_regression_branch_accuracy: 0.9062 - val_classification_branch_accuracy: 0.3875
# Epoch 44/60
# 43/43 [==============================] - 62s 1s/step - loss: 0.3001 - regression_branch_loss: 0.1931 - classification_branch_loss: 0.1071 - regression_branch_accuracy: 0.7604 - classification_branch_accuracy: 0.8571 - val_loss: 1.9519 - val_regression_branch_loss: 1.1374 - val_classification_branch_loss: 0.8145 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.4563
# Epoch 45/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2957 - regression_branch_loss: 0.1872 - classification_branch_loss: 0.1085 - regression_branch_accuracy: 0.7531 - classification_branch_accuracy: 0.8637 - val_loss: 1.8832 - val_regression_branch_loss: 1.0814 - val_classification_branch_loss: 0.8018 - val_regression_branch_accuracy: 0.8813 - val_classification_branch_accuracy: 0.4563
# Epoch 46/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2871 - regression_branch_loss: 0.1777 - classification_branch_loss: 0.1094 - regression_branch_accuracy: 0.7326 - classification_branch_accuracy: 0.8586 - val_loss: 1.7885 - val_regression_branch_loss: 1.0718 - val_classification_branch_loss: 0.7167 - val_regression_branch_accuracy: 0.8938 - val_classification_branch_accuracy: 0.5000
# Epoch 47/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2711 - regression_branch_loss: 0.1667 - classification_branch_loss: 0.1044 - regression_branch_accuracy: 0.7619 - classification_branch_accuracy: 0.8205 - val_loss: 1.6855 - val_regression_branch_loss: 0.9937 - val_classification_branch_loss: 0.6917 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5188
# Epoch 48/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2749 - regression_branch_loss: 0.1678 - classification_branch_loss: 0.1072 - regression_branch_accuracy: 0.7810 - classification_branch_accuracy: 0.8315 - val_loss: 1.9303 - val_regression_branch_loss: 1.2039 - val_classification_branch_loss: 0.7263 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.4875
# Epoch 49/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2672 - regression_branch_loss: 0.1738 - classification_branch_loss: 0.0934 - regression_branch_accuracy: 0.7546 - classification_branch_accuracy: 0.8740 - val_loss: 2.0064 - val_regression_branch_loss: 1.1920 - val_classification_branch_loss: 0.8143 - val_regression_branch_accuracy: 0.9062 - val_classification_branch_accuracy: 0.4437
# Epoch 50/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2732 - regression_branch_loss: 0.1745 - classification_branch_loss: 0.0987 - regression_branch_accuracy: 0.7626 - classification_branch_accuracy: 0.8403 - val_loss: 1.9320 - val_regression_branch_loss: 1.1216 - val_classification_branch_loss: 0.8104 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.4437
# Epoch 51/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2367 - regression_branch_loss: 0.1443 - classification_branch_loss: 0.0925 - regression_branch_accuracy: 0.7553 - classification_branch_accuracy: 0.8132 - val_loss: 1.6794 - val_regression_branch_loss: 1.0822 - val_classification_branch_loss: 0.5972 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5750
# Epoch 52/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2439 - regression_branch_loss: 0.1582 - classification_branch_loss: 0.0856 - regression_branch_accuracy: 0.7575 - classification_branch_accuracy: 0.8571 - val_loss: 1.5574 - val_regression_branch_loss: 0.9828 - val_classification_branch_loss: 0.5747 - val_regression_branch_accuracy: 0.9125 - val_classification_branch_accuracy: 0.6250
# Epoch 53/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2435 - regression_branch_loss: 0.1485 - classification_branch_loss: 0.0949 - regression_branch_accuracy: 0.7802 - classification_branch_accuracy: 0.8586 - val_loss: 1.7466 - val_regression_branch_loss: 1.0971 - val_classification_branch_loss: 0.6495 - val_regression_branch_accuracy: 0.9062 - val_classification_branch_accuracy: 0.5500
# Epoch 54/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2287 - regression_branch_loss: 0.1399 - classification_branch_loss: 0.0889 - regression_branch_accuracy: 0.7546 - classification_branch_accuracy: 0.8498 - val_loss: 1.5874 - val_regression_branch_loss: 0.9732 - val_classification_branch_loss: 0.6142 - val_regression_branch_accuracy: 0.9125 - val_classification_branch_accuracy: 0.5813
# Epoch 55/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2366 - regression_branch_loss: 0.1519 - classification_branch_loss: 0.0847 - regression_branch_accuracy: 0.7575 - classification_branch_accuracy: 0.8476 - val_loss: 1.6384 - val_regression_branch_loss: 0.9665 - val_classification_branch_loss: 0.6719 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5688
# Epoch 56/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2317 - regression_branch_loss: 0.1461 - classification_branch_loss: 0.0856 - regression_branch_accuracy: 0.7429 - classification_branch_accuracy: 0.8711 - val_loss: 2.1376 - val_regression_branch_loss: 1.2572 - val_classification_branch_loss: 0.8803 - val_regression_branch_accuracy: 0.9125 - val_classification_branch_accuracy: 0.5063
# Epoch 57/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2318 - regression_branch_loss: 0.1465 - classification_branch_loss: 0.0853 - regression_branch_accuracy: 0.7465 - classification_branch_accuracy: 0.8630 - val_loss: 2.0457 - val_regression_branch_loss: 1.1788 - val_classification_branch_loss: 0.8668 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.4875
# Epoch 58/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2369 - regression_branch_loss: 0.1560 - classification_branch_loss: 0.0810 - regression_branch_accuracy: 0.7568 - classification_branch_accuracy: 0.8440 - val_loss: 1.5942 - val_regression_branch_loss: 0.9857 - val_classification_branch_loss: 0.6085 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.5625
# Epoch 59/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2344 - regression_branch_loss: 0.1446 - classification_branch_loss: 0.0898 - regression_branch_accuracy: 0.7634 - classification_branch_accuracy: 0.8476 - val_loss: 1.6546 - val_regression_branch_loss: 1.0026 - val_classification_branch_loss: 0.6520 - val_regression_branch_accuracy: 0.9187 - val_classification_branch_accuracy: 0.6250
# Epoch 60/60
# 43/43 [==============================] - 59s 1s/step - loss: 0.2124 - regression_branch_loss: 0.1366 - classification_branch_loss: 0.0758 - regression_branch_accuracy: 0.7714 - classification_branch_accuracy: 0.8315 - val_loss: 1.7884 - val_regression_branch_loss: 1.1162 - val_classification_branch_loss: 0.6721 - val_regression_branch_accuracy: 0.9250 - val_classification_branch_accuracy: 0.5688

# %%
# Plotting the Training and Validation Accuracies and Losses.
def plot_training_history(history, epochs):
    regression_branch_accuracy = history.history['regression_branch_accuracy']
    regression_branch_loss = history.history['regression_branch_loss']

    classification_branch_accuracy = history.history['classification_branch_accuracy']
    classification_branch_loss = history.history['classification_branch_loss']
    
    val_regression_branch_accuracy = history.history['val_regression_branch_accuracy']
    val_regression_branch_loss = history.history['val_regression_branch_loss']
    
    val_classification_branch_accuracy = history.history['val_classification_branch_accuracy']
    val_classification_branch_loss = history.history['val_classification_branch_loss']
    
    epochs = range(epochs)
 
    plt.figure(figsize=(15, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, regression_branch_accuracy, 'r-', label='regression branch accuracy')
    plt.plot(epochs, classification_branch_accuracy, 'b', label='classification branch accuracy')
    plt.plot(epochs, val_classification_branch_accuracy, 'g', label='val classification branch accuracy')
    plt.plot(epochs, val_regression_branch_accuracy, 'y', label='val regression branch accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
 
    plt.subplot(1, 2, 2)
    plt.plot(epochs, regression_branch_loss, 'r', label='regression branch loss')
    plt.plot(epochs, classification_branch_loss, 'b', label='classification branch loss')
    plt.plot(epochs, val_classification_branch_loss, 'g', label='val classification branch loss')
    plt.plot(epochs, val_regression_branch_loss, 'y', label='val regression branch loss')
    plt.title('Training and validation Loss')
    plt.legend()
 
    plt.show()

# %%
plot_training_history(history, epochs)

# %% [markdown]
# # ***Evaluate The Model***

# %%
def best_model(model1, model2, testing_steps):
  a = model1.evaluate_generator(test_generator, testing_steps)
  b = model2.evaluate_generator(test_generator, testing_steps)
  if a[-2] + a[-1] >= b[-2] + b[-1]:
    model1.save('/content/drive/MyDrive/task/best_mob_model.h5')
    print('The Best Model Accuracies are :-         ')
    print('Accuracy of the Regression Part is :-    ', a[-2] * 100)
    print('Accuracy of the Classification Part is :-', a[-1] * 100)
  else:
    model2.save('/content/drive/MyDrive/task/best_mob_model.h5')
    print('The Best Model Accuracies are :-         ')
    print('Accuracy of the Regression Part is :-    ', b[-2] * 100)
    print('Accuracy of the Classification Part is :-', b[-1] * 100)

# %%
# Get the Best Model
model1 = load_model('/content/drive/MyDrive/task/mobnet_val_regression_branch_loss.model.hdf5')
model2 = load_model('/content/drive/MyDrive/task/mobnet_val_classification_branch_loss.model.hdf5')
best_model(model1, model2, testing_steps)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# The Best Model Accuracies are :-
# Accuracy of the Regression Part is :-     89.14285898208618
# Accuracy of the Classification Part is :- 46.85714244842529

# %%
datagen = ImageDataGenerator(rescale = 1./255)

all_generator = split_outputs(datagen.flow_from_dataframe(dataframe = data_frame, directory = '/content/drive/MyDrive/task/Coffee Leaves/images/',
                                                    x_col = 'id', y_col = targets, batch_size = batch_size, seed = 42, shuffle = False,
                                                    class_mode = 'raw', target_size = (224, 224)))
# Out:
# Found 1747 validated image filenames.

# %%
best_model = load_model('/content/drive/MyDrive/task/best_mob_model.h5')
acc = model1.evaluate_generator(all_generator, 32)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '

# %%
print('Accuracy of the Regression Part is :-    ', acc[-2] * 100)
print('Accuracy of the Classification Part is :-', acc[-1] * 100)
# Out:
# Accuracy of the Regression Part is :-     65.72265625
# Accuracy of the Classification Part is :- 89.16015625
